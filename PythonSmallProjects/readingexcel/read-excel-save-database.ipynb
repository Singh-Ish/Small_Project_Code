# %%
import pandas as pd
import pymongo
import json

from pymongo import MongoClient

# %%
df= pd.read_excel('projectDetails.xlsx')

df
# Out:
#      groupNo                                              title supervisor  \
# 0        1.0  Crowd-source grocery store layouts for dy-mica...      Green
# 1        NaN                                                NaN        NaN
# 2        NaN                                                NaN        NaN
# 3        2.0         A Toolkit for Constructing Covert Channels   Jaskolka
# 4        NaN                                                NaN        NaN
# ..       ...                                                ...        ...
# 206     69.0                                          Topic TBC       Taha
# 207      NaN                                                NaN        NaN
# 208      NaN                                                NaN        NaN
# 209     70.0                      Energy Consumption Prediction      Ajila
# 210      NaN                                                NaN        NaN
#
#     coSupervisor     userId lastName firstName  assessmentStatus
# 0              -  101009713     Khan    Haseeb                 0
# 1            NaN  101006153   Mathew     Jobin                 0
# 2            NaN  100997482      Sr-   Abraham                 1
# 3              -  101007628  Abraham      Ryan                 0
# 4            NaN  101024632   Dysart   Michael                 0
# ..           ...        ...      ...       ...               ...
# 206         Atia  101050477   Turner      John                 0
# 207          NaN  101023182    Vuong     Aaron                 0
# 208          NaN  101027686     Wang     Alden                 0
# 209            -  101054547    Mehdi      Zoha                 0
# 210          NaN  101039656    Singh  Amandeep                 0
#
# [211 rows x 8 columns]

# %%
df = df.fillna(method='ffill') # handling the merged cell data 
df
# Out:
#      groupNo                                              title supervisor  \
# 0        1.0  Crowd-source grocery store layouts for dy-mica...      Green
# 1        1.0  Crowd-source grocery store layouts for dy-mica...      Green
# 2        1.0  Crowd-source grocery store layouts for dy-mica...      Green
# 3        2.0         A Toolkit for Constructing Covert Channels   Jaskolka
# 4        2.0         A Toolkit for Constructing Covert Channels   Jaskolka
# ..       ...                                                ...        ...
# 206     69.0                                          Topic TBC       Taha
# 207     69.0                                          Topic TBC       Taha
# 208     69.0                                          Topic TBC       Taha
# 209     70.0                      Energy Consumption Prediction      Ajila
# 210     70.0                      Energy Consumption Prediction      Ajila
#
#     coSupervisor     userId lastName firstName  assessmentStatus
# 0              -  101009713     Khan    Haseeb                 0
# 1              -  101006153   Mathew     Jobin                 0
# 2              -  100997482      Sr-   Abraham                 1
# 3              -  101007628  Abraham      Ryan                 0
# 4              -  101024632   Dysart   Michael                 0
# ..           ...        ...      ...       ...               ...
# 206         Atia  101050477   Turner      John                 0
# 207         Atia  101023182    Vuong     Aaron                 0
# 208         Atia  101027686     Wang     Alden                 0
# 209            -  101054547    Mehdi      Zoha                 0
# 210            -  101039656    Singh  Amandeep                 0
#
# [211 rows x 8 columns]

# %%
df.dtypes
# Out:
# groupNo             float64
# title                object
# supervisor           object
# coSupervisor         object
# userId                int64
# lastName             object
# firstName            object
# assessmentStatus      int64
# dtype: object

# %%
df.groupNo = df.groupNo.astype(int)
df.userId = df.userId.astype(int)
df.coSupervisor = df.coSupervisor.astype(object)
df.assessmentStatus = df.assessmentStatus.astype(int)

# %%
df = df.drop_duplicates() # removing the duplication enteries and creating a new dataframe df 
df
# Out:
#      groupNo                                              title supervisor  \
# 0          1  Crowd-source grocery store layouts for dy-mica...      Green
# 1          1  Crowd-source grocery store layouts for dy-mica...      Green
# 2          1  Crowd-source grocery store layouts for dy-mica...      Green
# 3          2         A Toolkit for Constructing Covert Channels   Jaskolka
# 4          2         A Toolkit for Constructing Covert Channels   Jaskolka
# ..       ...                                                ...        ...
# 206       69                                          Topic TBC       Taha
# 207       69                                          Topic TBC       Taha
# 208       69                                          Topic TBC       Taha
# 209       70                      Energy Consumption Prediction      Ajila
# 210       70                      Energy Consumption Prediction      Ajila
#
#     coSupervisor     userId lastName firstName  assessmentStatus
# 0              -  101009713     Khan    Haseeb                 0
# 1              -  101006153   Mathew     Jobin                 0
# 2              -  100997482      Sr-   Abraham                 1
# 3              -  101007628  Abraham      Ryan                 0
# 4              -  101024632   Dysart   Michael                 0
# ..           ...        ...      ...       ...               ...
# 206         Atia  101050477   Turner      John                 0
# 207         Atia  101023182    Vuong     Aaron                 0
# 208         Atia  101027686     Wang     Alden                 0
# 209            -  101054547    Mehdi      Zoha                 0
# 210            -  101039656    Singh  Amandeep                 0
#
# [211 rows x 8 columns]

# %%
list(df.columns)
# Out:
# ['groupNo',
#  'title',
#  'supervisor',
#  'coSupervisor',
#  'userId',
#  'lastName',
#  'firstName',
#  'assessmentStatus']

# %%
jf= df.to_json(orient='records') # converting datframes 
jf_data = json.loads(jf) # converting to dictionary 
jf_data

with open('projects.json','w') as f:
    json.dump(jf_data,f)

# %%
#Connecting to Mondo db databse 
# mongo db settings 
client = MongoClient("mongodb://localhost:27017/")
mydb = client["assessment"]
db = mydb["projects"]

# %%
jf_data
# Out:
# [{'groupNo': 1,
#   'title': 'Crowd-source grocery store layouts for dy-mically sorted shopping lists',
#   'supervisor': 'Green',
#   'coSupervisor': '-',
#   'userId': 101009713,
#   'lastName': 'Khan',
#   'firstName': 'Haseeb',
#   'assessmentStatus': 0},
#  {'groupNo': 1,
#   'title': 'Crowd-source grocery store layouts for dy-mically sorted shopping lists',
#   'supervisor': 'Green',
#   'coSupervisor': '-',
#   'userId': 101006153,
#   'lastName': 'Mathew',
#   'firstName': 'Jobin',
#   'assessmentStatus': 0},
#  {'groupNo': 1,
#   'title': 'Crowd-source grocery store layouts for dy-mically sorted shopping lists',
#   'supervisor': 'Green',
#   'coSupervisor': '-',
#   'userId': 100997482,
#   'lastName': 'Sr-',
#   'firstName': 'Abraham',
#   'assessmentStatus': 1},
#  {'groupNo': 2,
#   'title': 'A Toolkit for Constructing Covert Channels',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 101007628,
#   'lastName': 'Abraham',
#   'firstName': 'Ryan',
#   'assessmentStatus': 0},
#  {'groupNo': 2,
#   'title': 'A Toolkit for Constructing Covert Channels',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 101024632,
#   'lastName': 'Dysart',
#   'firstName': 'Michael',
#   'assessmentStatus': 0},
#  {'groupNo': 2,
#   'title': 'A Toolkit for Constructing Covert Channels',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 101012629,
#   'lastName': 'Hanumunthadu',
#   'firstName': 'Dhari-',
#   'assessmentStatus': 0},
#  {'groupNo': 2,
#   'title': 'A Toolkit for Constructing Covert Channels',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 100997764,
#   'lastName': 'Man',
#   'firstName': 'Fahid',
#   'assessmentStatus': 0},
#  {'groupNo': 2,
#   'title': 'A Toolkit for Constructing Covert Channels',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 101003006,
#   'lastName': 'Schoenermarck',
#   'firstName': 'Jackson',
#   'assessmentStatus': 0},
#  {'groupNo': 3,
#   'title': 'Pattern Classification Challenges in Bioinformatics',
#   'supervisor': 'Green',
#   'coSupervisor': '-',
#   'userId': 101003507,
#   'lastName': 'Kyrollos',
#   'firstName': 'Daniel',
#   'assessmentStatus': 0},
#  {'groupNo': 3,
#   'title': 'Pattern Classification Challenges in Bioinformatics',
#   'supervisor': 'Green',
#   'coSupervisor': '-',
#   'userId': 100994250,
#   'lastName': 'Reid',
#   'firstName': 'Bradley',
#   'assessmentStatus': 0},
#  {'groupNo': 4,
#   'title': 'Train Early Detection System',
#   'supervisor': 'Kunz',
#   'coSupervisor': '-',
#   'userId': 101004770,
#   'lastName': 'Kirby',
#   'firstName': 'Callum',
#   'assessmentStatus': 0},
#  {'groupNo': 4,
#   'title': 'Train Early Detection System',
#   'supervisor': 'Kunz',
#   'coSupervisor': '-',
#   'userId': 100997792,
#   'lastName': 'MacGillivray',
#   'firstName': 'Logan',
#   'assessmentStatus': 0},
#  {'groupNo': 4,
#   'title': 'Train Early Detection System',
#   'supervisor': 'Kunz',
#   'coSupervisor': '-',
#   'userId': 101013786,
#   'lastName': 'Mol-r',
#   'firstName': 'Christopher',
#   'assessmentStatus': 0},
#  {'groupNo': 5,
#   'title': 'Attack Surface A-lysis and Measurement',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 100998411,
#   'lastName': 'Bichel',
#   'firstName': 'Benjamin',
#   'assessmentStatus': 0},
#  {'groupNo': 5,
#   'title': 'Attack Surface A-lysis and Measurement',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 101006779,
#   'lastName': 'Dawoud',
#   'firstName': 'Omar',
#   'assessmentStatus': 0},
#  {'groupNo': 5,
#   'title': 'Attack Surface A-lysis and Measurement',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 100966499,
#   'lastName': 'Holden',
#   'firstName': 'Darren',
#   'assessmentStatus': 0},
#  {'groupNo': 5,
#   'title': 'Attack Surface A-lysis and Measurement',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 100997226,
#   'lastName': 'Hubert',
#   'firstName': 'Gabrielle',
#   'assessmentStatus': 0},
#  {'groupNo': 5,
#   'title': 'Attack Surface A-lysis and Measurement',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 101004427,
#   'lastName': 'Macdougall',
#   'firstName': 'Jack',
#   'assessmentStatus': 0},
#  {'groupNo': 6,
#   'title': 'Real-Time Collaboration Messaging Web Application',
#   'supervisor': 'Schramm',
#   'coSupervisor': '-',
#   'userId': 100997443,
#   'lastName': 'Le-Phuong',
#   'firstName': 'Thao-Tran',
#   'assessmentStatus': 0},
#  {'groupNo': 6,
#   'title': 'Real-Time Collaboration Messaging Web Application',
#   'supervisor': 'Schramm',
#   'coSupervisor': '-',
#   'userId': 101008909,
#   'lastName': 'Lopes',
#   'firstName': 'Honor ',
#   'assessmentStatus': 0},
#  {'groupNo': 6,
#   'title': 'Real-Time Collaboration Messaging Web Application',
#   'supervisor': 'Schramm',
#   'coSupervisor': '-',
#   'userId': 100996542,
#   'lastName': 'MacKinnon',
#   'firstName': 'Mary',
#   'assessmentStatus': 0},
#  {'groupNo': 6,
#   'title': 'Real-Time Collaboration Messaging Web Application',
#   'supervisor': 'Schramm',
#   'coSupervisor': '-',
#   'userId': 101011081,
#   'lastName': 'Veselinovic',
#   'firstName': 'Igor',
#   'assessmentStatus': 0},
#  {'groupNo': 7,
#   'title': 'Biological Robot',
#   'supervisor': 'Liu',
#   'coSupervisor': '-',
#   'userId': 100995206,
#   'lastName': 'Hu',
#   'firstName': 'Zeqi',
#   'assessmentStatus': 0},
#  {'groupNo': 7,
#   'title': 'Biological Robot',
#   'supervisor': 'Liu',
#   'coSupervisor': '-',
#   'userId': 101019972,
#   'lastName': 'Jia',
#   'firstName': "Yan'Ang",
#   'assessmentStatus': 0},
#  {'groupNo': 7,
#   'title': 'Biological Robot',
#   'supervisor': 'Liu',
#   'coSupervisor': '-',
#   'userId': 101025954,
#   'lastName': 'Tao',
#   'firstName': 'Chutian',
#   'assessmentStatus': 0},
#  {'groupNo': 7,
#   'title': 'Biological Robot',
#   'supervisor': 'Liu',
#   'coSupervisor': '-',
#   'userId': 101031438,
#   'lastName': 'Xia',
#   'firstName': 'Yijie ',
#   'assessmentStatus': 0},
#  {'groupNo': 7,
#   'title': 'Biological Robot',
#   'supervisor': 'Liu',
#   'coSupervisor': '-',
#   'userId': 101047510,
#   'lastName': 'Zou',
#   'firstName': 'Baixi',
#   'assessmentStatus': 0},
#  {'groupNo': 8,
#   'title': 'An intelligent web crawler',
#   'supervisor': 'Huang',
#   'coSupervisor': '-',
#   'userId': 101000491,
#   'lastName': 'Chau',
#   'firstName': 'Tuan',
#   'assessmentStatus': 0},
#  {'groupNo': 8,
#   'title': 'An intelligent web crawler',
#   'supervisor': 'Huang',
#   'coSupervisor': '-',
#   'userId': 100935765,
#   'lastName': 'Faizan',
#   'firstName': 'Ali',
#   'assessmentStatus': 0},
#  {'groupNo': 8,
#   'title': 'An intelligent web crawler',
#   'supervisor': 'Huang',
#   'coSupervisor': '-',
#   'userId': 101026761,
#   'lastName': 'Qiao',
#   'firstName': 'Zhi',
#   'assessmentStatus': 0},
#  {'groupNo': 8,
#   'title': 'An intelligent web crawler',
#   'supervisor': 'Huang',
#   'coSupervisor': '-',
#   'userId': 101031077,
#   'lastName': 'Tyler',
#   'firstName': 'Cole',
#   'assessmentStatus': 0},
#  {'groupNo': 9,
#   'title': 'Mobile App version of Dendroica',
#   'supervisor': 'Schramm',
#   'coSupervisor': '-',
#   'userId': 100935515,
#   'lastName': 'Aljabri',
#   'firstName': 'Hussain',
#   'assessmentStatus': 0},
#  {'groupNo': 9,
#   'title': 'Mobile App version of Dendroica',
#   'supervisor': 'Schramm',
#   'coSupervisor': '-',
#   'userId': 101015807,
#   'lastName': 'Van Gool',
#   'firstName': 'Robyn',
#   'assessmentStatus': 0},
#  {'groupNo': 9,
#   'title': 'Mobile App version of Dendroica',
#   'supervisor': 'Schramm',
#   'coSupervisor': '-',
#   'userId': 100908473,
#   'lastName': 'Yastrebov',
#   'firstName': 'Vadim',
#   'assessmentStatus': 0},
#  {'groupNo': 10,
#   'title': 'Real-time sit to stand mobility a-lysis',
#   'supervisor': 'Green',
#   'coSupervisor': 'Wallace',
#   'userId': 100995046,
#   'lastName': 'El-Astal ',
#   'firstName': 'Layan',
#   'assessmentStatus': 0},
#  {'groupNo': 10,
#   'title': 'Real-time sit to stand mobility a-lysis',
#   'supervisor': 'Green',
#   'coSupervisor': 'Wallace',
#   'userId': 100968704,
#   'lastName': 'Ji',
#   'firstName': 'Zhe',
#   'assessmentStatus': 0},
#  {'groupNo': 10,
#   'title': 'Real-time sit to stand mobility a-lysis',
#   'supervisor': 'Green',
#   'coSupervisor': 'Wallace',
#   'userId': 100982445,
#   'lastName': 'Liu',
#   'firstName': 'Haoyang',
#   'assessmentStatus': 0},
#  {'groupNo': 11,
#   'title': 'Data Visualization for Autonomous Vehicles',
#   'supervisor': 'Gohary',
#   'coSupervisor': 'Lambadaris',
#   'userId': 101011524,
#   'lastName': 'Cassis',
#   'firstName': 'Keyan',
#   'assessmentStatus': 0},
#  {'groupNo': 11,
#   'title': 'Data Visualization for Autonomous Vehicles',
#   'supervisor': 'Gohary',
#   'coSupervisor': 'Lambadaris',
#   'userId': 101012663,
#   'lastName': '-ida',
#   'firstName': 'Philip',
#   'assessmentStatus': 0},
#  {'groupNo': 11,
#   'title': 'Data Visualization for Autonomous Vehicles',
#   'supervisor': 'Gohary',
#   'coSupervisor': 'Lambadaris',
#   'userId': 101008219,
#   'lastName': 'Pruss',
#   'firstName': 'Michael',
#   'assessmentStatus': 0},
#  {'groupNo': 11,
#   'title': 'Data Visualization for Autonomous Vehicles',
#   'supervisor': 'Gohary',
#   'coSupervisor': 'Lambadaris',
#   'userId': 100969837,
#   'lastName': 'Skalecki',
#   'firstName': 'Michael',
#   'assessmentStatus': 0},
#  {'groupNo': 11,
#   'title': 'Data Visualization for Autonomous Vehicles',
#   'supervisor': 'Gohary',
#   'coSupervisor': 'Lambadaris',
#   'userId': 100999548,
#   'lastName': 'Vucetic',
#   'firstName': 'Danilo',
#   'assessmentStatus': 0},
#  {'groupNo': 12,
#   'title': 'CANImmunize Web Client Redesign',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 101051047,
#   'lastName': 'Garg',
#   'firstName': 'Tanisha',
#   'assessmentStatus': 0},
#  {'groupNo': 12,
#   'title': 'CANImmunize Web Client Redesign',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 101018695,
#   'lastName': 'Sakr',
#   'firstName': 'Ahmed',
#   'assessmentStatus': 0},
#  {'groupNo': 12,
#   'title': 'CANImmunize Web Client Redesign',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 101010041,
#   'lastName': 'Verge',
#   'firstName': 'Devon',
#   'assessmentStatus': 0},
#  {'groupNo': 13,
#   'title': 'Robust Identifiation of Human Faces',
#   'supervisor': 'Banihashemi',
#   'coSupervisor': '-',
#   'userId': 100962136,
#   'lastName': 'Anton',
#   'firstName': 'Harshan',
#   'assessmentStatus': 0},
#  {'groupNo': 13,
#   'title': 'Robust Identifiation of Human Faces',
#   'supervisor': 'Banihashemi',
#   'coSupervisor': '-',
#   'userId': 101007533,
#   'lastName': 'Arava',
#   'firstName': 'Jo-than',
#   'assessmentStatus': 0},
#  {'groupNo': 13,
#   'title': 'Robust Identifiation of Human Faces',
#   'supervisor': 'Banihashemi',
#   'coSupervisor': '-',
#   'userId': 101018187,
#   'lastName': 'Dimitrov',
#   'firstName': 'Viktor',
#   'assessmentStatus': 0},
#  {'groupNo': 15,
#   'title': 'Real-time patient monitoring app for the CHEO neo-tal patient transport team',
#   'supervisor': 'Green',
#   'coSupervisor': '-',
#   'userId': 101001771,
#   'lastName': 'Blidaru',
#   'firstName': 'Teodora',
#   'assessmentStatus': 0},
#  {'groupNo': 15,
#   'title': 'Real-time patient monitoring app for the CHEO neo-tal patient transport team',
#   'supervisor': 'Green',
#   'coSupervisor': '-',
#   'userId': 101006952,
#   'lastName': 'Contreras',
#   'firstName': 'Juan',
#   'assessmentStatus': 0},
#  {'groupNo': 15,
#   'title': 'Real-time patient monitoring app for the CHEO neo-tal patient transport team',
#   'supervisor': 'Green',
#   'coSupervisor': '-',
#   'userId': 101009798,
#   'lastName': 'Gryfe',
#   'firstName': 'Caleb',
#   'assessmentStatus': 0},
#  {'groupNo': 16,
#   'title': 'Confidentiality Preservation in Big Data Centres',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 101004428,
#   'lastName': 'Akhand',
#   'firstName': 'Tashfiq',
#   'assessmentStatus': 0},
#  {'groupNo': 16,
#   'title': 'Confidentiality Preservation in Big Data Centres',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 100921446,
#   'lastName': 'Issa',
#   'firstName': 'Hasan',
#   'assessmentStatus': 0},
#  {'groupNo': 16,
#   'title': 'Confidentiality Preservation in Big Data Centres',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 100999110,
#   'lastName': 'Savic',
#   'firstName': 'Aleksandar',
#   'assessmentStatus': 0},
#  {'groupNo': 16,
#   'title': 'Confidentiality Preservation in Big Data Centres',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 100999332,
#   'lastName': 'Soong',
#   'firstName': 'Calvin',
#   'assessmentStatus': 0},
#  {'groupNo': 16,
#   'title': 'Confidentiality Preservation in Big Data Centres',
#   'supervisor': 'Jaskolka',
#   'coSupervisor': '-',
#   'userId': 100996797,
#   'lastName': 'Zheng',
#   'firstName': 'Zihao',
#   'assessmentStatus': 0},
#  {'groupNo': 17,
#   'title': 'Building Internet of Things (IoT) using Web services and edge computing for a visitor ma-gement system',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101019254,
#   'lastName': 'Luo',
#   'firstName': 'Lixuan',
#   'assessmentStatus': 0},
#  {'groupNo': 17,
#   'title': 'Building Internet of Things (IoT) using Web services and edge computing for a visitor ma-gement system',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101014341,
#   'lastName': 'Zhang',
#   'firstName': 'Pengliang ',
#   'assessmentStatus': 1},
#  {'groupNo': 17,
#   'title': 'Building Internet of Things (IoT) using Web services and edge computing for a visitor ma-gement system',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101018373,
#   'lastName': 'Zhang',
#   'firstName': 'Haohan',
#   'assessmentStatus': 0},
#  {'groupNo': 17,
#   'title': 'Building Internet of Things (IoT) using Web services and edge computing for a visitor ma-gement system',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101057752,
#   'lastName': 'Zhu',
#   'firstName': 'Tongdan',
#   'assessmentStatus': 0},
#  {'groupNo': 18,
#   'title': 'A driving environment emulator for testing the intelligence of autonomous vehicles',
#   'supervisor': 'Huang',
#   'coSupervisor': '-',
#   'userId': 100971104,
#   'lastName': 'Cao',
#   'firstName': 'Bohua',
#   'assessmentStatus': 0},
#  {'groupNo': 18,
#   'title': 'A driving environment emulator for testing the intelligence of autonomous vehicles',
#   'supervisor': 'Huang',
#   'coSupervisor': '-',
#   'userId': 100967203,
#   'lastName': 'Li',
#   'firstName': 'Gen',
#   'assessmentStatus': 0},
#  {'groupNo': 18,
#   'title': 'A driving environment emulator for testing the intelligence of autonomous vehicles',
#   'supervisor': 'Huang',
#   'coSupervisor': '-',
#   'userId': 101016463,
#   'lastName': 'Pang',
#   'firstName': 'Hongbo',
#   'assessmentStatus': 0},
#  {'groupNo': 18,
#   'title': 'A driving environment emulator for testing the intelligence of autonomous vehicles',
#   'supervisor': 'Huang',
#   'coSupervisor': '-',
#   'userId': 100980200,
#   'lastName': 'Shen',
#   'firstName': 'Weihong',
#   'assessmentStatus': 0},
#  {'groupNo': 19,
#   'title': 'Tool framework to measure test case diversity',
#   'supervisor': 'Labiche',
#   'coSupervisor': '-',
#   'userId': 101009607,
#   'lastName': 'Bedard',
#   'firstName': 'Eric',
#   'assessmentStatus': 0},
#  {'groupNo': 19,
#   'title': 'Tool framework to measure test case diversity',
#   'supervisor': 'Labiche',
#   'coSupervisor': '-',
#   'userId': 100999309,
#   'lastName': 'Newton',
#   'firstName': 'Luke',
#   'assessmentStatus': 0},
#  {'groupNo': 19,
#   'title': 'Tool framework to measure test case diversity',
#   'supervisor': 'Labiche',
#   'coSupervisor': '-',
#   'userId': 101002958,
#   'lastName': 'Rushton',
#   'firstName': 'Cameron',
#   'assessmentStatus': 0},
#  {'groupNo': 20,
#   'title': 'Hand and Forearm Rehabilitation Monitoring',
#   'supervisor': 'Adler',
#   'coSupervisor': '-',
#   'userId': 101031998,
#   'lastName': 'Hayles',
#   'firstName': 'Joshua',
#   'assessmentStatus': 0},
#  {'groupNo': 20,
#   'title': 'Hand and Forearm Rehabilitation Monitoring',
#   'supervisor': 'Adler',
#   'coSupervisor': '-',
#   'userId': 101029022,
#   'lastName': 'Ross',
#   'firstName': 'Bay',
#   'assessmentStatus': 0},
#  {'groupNo': 20,
#   'title': 'Hand and Forearm Rehabilitation Monitoring',
#   'supervisor': 'Adler',
#   'coSupervisor': '-',
#   'userId': 101012848,
#   'lastName': 'Stewart',
#   'firstName': 'Mary',
#   'assessmentStatus': 0},
#  {'groupNo': 21,
#   'title': 'Logisim replacement',
#   'supervisor': 'Franks',
#   'coSupervisor': '-',
#   'userId': 101032335,
#   'lastName': 'Fryer',
#   'firstName': 'Joshua',
#   'assessmentStatus': 0},
#  {'groupNo': 21,
#   'title': 'Logisim replacement',
#   'supervisor': 'Franks',
#   'coSupervisor': '-',
#   'userId': 100941844,
#   'lastName': 'Fundarek',
#   'firstName': 'Matthew',
#   'assessmentStatus': 0},
#  {'groupNo': 21,
#   'title': 'Logisim replacement',
#   'supervisor': 'Franks',
#   'coSupervisor': '-',
#   'userId': 101010131,
#   'lastName': 'Hemmingsen-Beriault',
#   'firstName': 'Kaj',
#   'assessmentStatus': 0},
#  {'groupNo': 21,
#   'title': 'Logisim replacement',
#   'supervisor': 'Franks',
#   'coSupervisor': '-',
#   'userId': 101038042,
#   'lastName': 'Horne',
#   'firstName': 'Kyle',
#   'assessmentStatus': 0},
#  {'groupNo': 22,
#   'title': 'Video a-lysis of mouse movements for neuroscience',
#   'supervisor': 'Adler',
#   'coSupervisor': '-',
#   'userId': 100889285,
#   'lastName': 'Gray',
#   'firstName': 'Rachael',
#   'assessmentStatus': 0},
#  {'groupNo': 22,
#   'title': 'Video a-lysis of mouse movements for neuroscience',
#   'supervisor': 'Adler',
#   'coSupervisor': '-',
#   'userId': 101038472,
#   'lastName': 'Hasmani',
#   'firstName': 'Mahima',
#   'assessmentStatus': 0},
#  {'groupNo': 22,
#   'title': 'Video a-lysis of mouse movements for neuroscience',
#   'supervisor': 'Adler',
#   'coSupervisor': '-',
#   'userId': 101058440,
#   'lastName': 'Parayaoan',
#   'firstName': 'Vanessa',
#   'assessmentStatus': 0},
#  {'groupNo': 23,
#   'title': 'Smart Sleep ',
#   'supervisor': 'Liu',
#   'coSupervisor': '-',
#   'userId': 100999317,
#   'lastName': 'Ahmed',
#   'firstName': 'Gazoan',
#   'assessmentStatus': 0},
#  {'groupNo': 23,
#   'title': 'Smart Sleep ',
#   'supervisor': 'Liu',
#   'coSupervisor': '-',
#   'userId': 101032342,
#   'lastName': 'Darwish',
#   'firstName': 'Riham',
#   'assessmentStatus': 0},
#  {'groupNo': 23,
#   'title': 'Smart Sleep ',
#   'supervisor': 'Liu',
#   'coSupervisor': '-',
#   'userId': 100997762,
#   'lastName': 'Massarani',
#   'firstName': 'Tarik',
#   'assessmentStatus': 0},
#  {'groupNo': 23,
#   'title': 'Smart Sleep ',
#   'supervisor': 'Liu',
#   'coSupervisor': '-',
#   'userId': 101006768,
#   'lastName': 'Wu',
#   'firstName': 'Mengyao',
#   'assessmentStatus': 0},
#  {'groupNo': 23,
#   'title': 'Smart Sleep ',
#   'supervisor': 'Liu',
#   'coSupervisor': '-',
#   'userId': 101027055,
#   'lastName': 'Zhang',
#   'firstName': 'Xinrui',
#   'assessmentStatus': 0},
#  {'groupNo': 24,
#   'title': 'X-2 Video Game',
#   'supervisor': 'Franks',
#   'coSupervisor': '-',
#   'userId': 101049347,
#   'lastName': 'Boucher',
#   'firstName': 'Ryan',
#   'assessmentStatus': 0},
#  {'groupNo': 24,
#   'title': 'X-2 Video Game',
#   'supervisor': 'Franks',
#   'coSupervisor': '-',
#   'userId': 100993125,
#   'lastName': 'Okwechime',
#   'firstName': 'N-mdi',
#   'assessmentStatus': 0},
#  {'groupNo': 24,
#   'title': 'X-2 Video Game',
#   'supervisor': 'Franks',
#   'coSupervisor': '-',
#   'userId': 100945382,
#   'lastName': 'Oudjida',
#   'firstName': 'Manel',
#   'assessmentStatus': 0},
#  {'groupNo': 24,
#   'title': 'X-2 Video Game',
#   'supervisor': 'Franks',
#   'coSupervisor': '-',
#   'userId': 101045797,
#   'lastName': 'Smith',
#   'firstName': 'Kyle',
#   'assessmentStatus': 0},
#  {'groupNo': 25,
#   'title': 'Image Detection of Migratory Birds',
#   'supervisor': 'Schramm',
#   'coSupervisor': '-',
#   'userId': 101004413,
#   'lastName': 'Dewilde',
#   'firstName': 'William',
#   'assessmentStatus': 0},
#  {'groupNo': 25,
#   'title': 'Image Detection of Migratory Birds',
#   'supervisor': 'Schramm',
#   'coSupervisor': '-',
#   'userId': 101002836,
#   'lastName': 'Myrah',
#   'firstName': 'Rachel',
#   'assessmentStatus': 0},
#  {'groupNo': 26,
#   'title': 'Erlang VM Cluster Behaviour In Golang',
#   'supervisor': 'Franks',
#   'coSupervisor': '-',
#   'userId': 101007498,
#   'lastName': 'Bombhi',
#   'firstName': 'Vikram',
#   'assessmentStatus': 0},
#  {'groupNo': 26,
#   'title': 'Erlang VM Cluster Behaviour In Golang',
#   'supervisor': 'Franks',
#   'coSupervisor': '-',
#   'userId': 101001982,
#   'lastName': 'Chiu',
#   'firstName': 'Jacky',
#   'assessmentStatus': 0},
#  {'groupNo': 26,
#   'title': 'Erlang VM Cluster Behaviour In Golang',
#   'supervisor': 'Franks',
#   'coSupervisor': '-',
#   'userId': 101003372,
#   'lastName': 'Rastogi',
#   'firstName': 'Kirin',
#   'assessmentStatus': 0},
#  {'groupNo': 26,
#   'title': 'Erlang VM Cluster Behaviour In Golang',
#   'supervisor': 'Franks',
#   'coSupervisor': '-',
#   'userId': 101008207,
#   'lastName': 'Zhang',
#   'firstName': 'Brian',
#   'assessmentStatus': 0},
#  {'groupNo': 27,
#   'title': 'Mobile graffiti/printer robot',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Gohary',
#   'userId': 101015128,
#   'lastName': 'Kras-y',
#   'firstName': 'Madelyn',
#   'assessmentStatus': 0},
#  {'groupNo': 27,
#   'title': 'Mobile graffiti/printer robot',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Gohary',
#   'userId': 101008256,
#   'lastName': 'Lam',
#   'firstName': 'Calvin',
#   'assessmentStatus': 0},
#  {'groupNo': 27,
#   'title': 'Mobile graffiti/printer robot',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Gohary',
#   'userId': 101001790,
#   'lastName': 'Mathias',
#   'firstName': 'Alyssa',
#   'assessmentStatus': 0},
#  {'groupNo': 27,
#   'title': 'Mobile graffiti/printer robot',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Gohary',
#   'userId': 100961942,
#   'lastName': 'Shi',
#   'firstName': 'Huishu',
#   'assessmentStatus': 0},
#  {'groupNo': 27,
#   'title': 'Mobile graffiti/printer robot',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Gohary',
#   'userId': 100970732,
#   'lastName': 'Wang',
#   'firstName': 'Zichen',
#   'assessmentStatus': 0},
#  {'groupNo': 28,
#   'title': 'Sensor Fusion for Smart Autonomous Systems',
#   'supervisor': 'Atia',
#   'coSupervisor': '-',
#   'userId': 100997458,
#   'lastName': 'Arid',
#   'firstName': 'Emad',
#   'assessmentStatus': 0},
#  {'groupNo': 28,
#   'title': 'Sensor Fusion for Smart Autonomous Systems',
#   'supervisor': 'Atia',
#   'coSupervisor': '-',
#   'userId': 101062340,
#   'lastName': 'Balogun',
#   'firstName': 'Oludare',
#   'assessmentStatus': 0},
#  {'groupNo': 28,
#   'title': 'Sensor Fusion for Smart Autonomous Systems',
#   'supervisor': 'Atia',
#   'coSupervisor': '-',
#   'userId': 100989250,
#   'lastName': 'Bhatia',
#   'firstName': 'Anya',
#   'assessmentStatus': 1},
#  {'groupNo': 28,
#   'title': 'Sensor Fusion for Smart Autonomous Systems',
#   'supervisor': 'Atia',
#   'coSupervisor': '-',
#   'userId': 101003545,
#   'lastName': 'Koloniaris',
#   'firstName': 'Gregory',
#   'assessmentStatus': 0},
#  {'groupNo': 28,
#   'title': 'Sensor Fusion for Smart Autonomous Systems',
#   'supervisor': 'Atia',
#   'coSupervisor': '-',
#   'userId': 101033653,
#   'lastName': 'Mushtaq',
#   'firstName': 'Zoya',
#   'assessmentStatus': 0},
#  {'groupNo': 29,
#   'title': 'Robotic guitar player',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Liu',
#   'userId': 101000120,
#   'lastName': 'Amladi',
#   'firstName': 'Shou-k',
#   'assessmentStatus': 0},
#  {'groupNo': 29,
#   'title': 'Robotic guitar player',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Liu',
#   'userId': 101000007,
#   'lastName': 'Bandemegala',
#   'firstName': 'Saisashank',
#   'assessmentStatus': 0},
#  {'groupNo': 29,
#   'title': 'Robotic guitar player',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Liu',
#   'userId': 101019954,
#   'lastName': 'Bansal',
#   'firstName': 'Rajat',
#   'assessmentStatus': 0},
#  {'groupNo': 29,
#   'title': 'Robotic guitar player',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Liu',
#   'userId': 101023655,
#   'lastName': 'Dipaolo',
#   'firstName': 'Nicholas',
#   'assessmentStatus': 0},
#  {'groupNo': 29,
#   'title': 'Robotic guitar player',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Liu',
#   'userId': 101008373,
#   'lastName': 'Patel',
#   'firstName': 'Brij',
#   'assessmentStatus': 0},
#  {'groupNo': 30,
#   'title': 'Activity of Daily Living Assessment - Stove/Oven use ',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Wallace',
#   'userId': 100977279,
#   'lastName': 'Alao',
#   'firstName': 'Obaloluwa',
#   'assessmentStatus': 0},
#  {'groupNo': 30,
#   'title': 'Activity of Daily Living Assessment - Stove/Oven use ',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Wallace',
#   'userId': 101008461,
#   'lastName': 'Jarikre',
#   'firstName': 'Efe',
#   'assessmentStatus': 0},
#  {'groupNo': 30,
#   'title': 'Activity of Daily Living Assessment - Stove/Oven use ',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Wallace',
#   'userId': 101001717,
#   'lastName': 'Tigere',
#   'firstName': 'Spencer',
#   'assessmentStatus': 0},
#  {'groupNo': 31,
#   'title': 'Simulated Autonomous Vehicle',
#   'supervisor': 'Esfandiari',
#   'coSupervisor': '-',
#   'userId': 101002918,
#   'lastName': 'Baak',
#   'firstName': 'James',
#   'assessmentStatus': 0},
#  {'groupNo': 31,
#   'title': 'Simulated Autonomous Vehicle',
#   'supervisor': 'Esfandiari',
#   'coSupervisor': '-',
#   'userId': 101002086,
#   'lastName': 'Gooderham',
#   'firstName': 'Maaike',
#   'assessmentStatus': 0},
#  {'groupNo': 32,
#   'title': 'NFC sensor-based information retrieval system',
#   'supervisor': 'Majumdar',
#   'coSupervisor': '-',
#   'userId': 101005281,
#   'lastName': 'Gerwing',
#   'firstName': 'Joshua',
#   'assessmentStatus': 0},
#  {'groupNo': 32,
#   'title': 'NFC sensor-based information retrieval system',
#   'supervisor': 'Majumdar',
#   'coSupervisor': '-',
#   'userId': 100998728,
#   'lastName': 'Huynh',
#   'firstName': 'An',
#   'assessmentStatus': 0},
#  {'groupNo': 32,
#   'title': 'NFC sensor-based information retrieval system',
#   'supervisor': 'Majumdar',
#   'coSupervisor': '-',
#   'userId': 101013886,
#   'lastName': 'Sigouin',
#   'firstName': 'Justin',
#   'assessmentStatus': 0},
#  {'groupNo': 33,
#   'title': 'From 3D space-modeling to autonomous robotic item handling',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Atia',
#   'userId': 101022643,
#   'lastName': 'Cook',
#   'firstName': 'Sebastien',
#   'assessmentStatus': 0},
#  {'groupNo': 33,
#   'title': 'From 3D space-modeling to autonomous robotic item handling',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Atia',
#   'userId': 101031617,
#   'lastName': 'Garde',
#   'firstName': 'Maveric',
#   'assessmentStatus': 0},
#  {'groupNo': 33,
#   'title': 'From 3D space-modeling to autonomous robotic item handling',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Atia',
#   'userId': 101041794,
#   'lastName': 'Hashi',
#   'firstName': 'Fatima',
#   'assessmentStatus': 0},
#  {'groupNo': 33,
#   'title': 'From 3D space-modeling to autonomous robotic item handling',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Atia',
#   'userId': 101035984,
#   'lastName': 'Raei',
#   'firstName': 'Nour',
#   'assessmentStatus': 0},
#  {'groupNo': 33,
#   'title': 'From 3D space-modeling to autonomous robotic item handling',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Atia',
#   'userId': 101000157,
#   'lastName': 'Sun',
#   'firstName': 'Kevin',
#   'assessmentStatus': 0},
#  {'groupNo': 35,
#   'title': 'Activity classification of older adults in kitchens',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Wallace',
#   'userId': 101004030,
#   'lastName': 'Abdulsalam',
#   'firstName': 'Abubakar',
#   'assessmentStatus': 0},
#  {'groupNo': 35,
#   'title': 'Activity classification of older adults in kitchens',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Wallace',
#   'userId': 101008516,
#   'lastName': 'Dhindsa',
#   'firstName': 'Gurveer',
#   'assessmentStatus': 0},
#  {'groupNo': 35,
#   'title': 'Activity classification of older adults in kitchens',
#   'supervisor': 'Garcia',
#   'coSupervisor': 'Wallace',
#   'userId': 101005880,
#   'lastName': 'Katkar',
#   'firstName': 'Rohan',
#   'assessmentStatus': 0},
#  {'groupNo': 36,
#   'title': 'Intelligent Telepresence and Assistive Device',
#   'supervisor': 'Coordi-tor',
#   'coSupervisor': '-',
#   'userId': 100962843,
#   'lastName': 'Cheung',
#   'firstName': 'Henri',
#   'assessmentStatus': 0},
#  {'groupNo': 38,
#   'title': 'Augmented Reality Application Development',
#   'supervisor': 'Rajan',
#   'coSupervisor': '-',
#   'userId': 100947181,
#   'lastName': 'Hamada Beaudry',
#   'firstName': 'Kukai',
#   'assessmentStatus': 0},
#  {'groupNo': 38,
#   'title': 'Augmented Reality Application Development',
#   'supervisor': 'Rajan',
#   'coSupervisor': '-',
#   'userId': 100996474,
#   'lastName': 'Laycano',
#   'firstName': 'Joseph',
#   'assessmentStatus': 0},
#  {'groupNo': 38,
#   'title': 'Augmented Reality Application Development',
#   'supervisor': 'Rajan',
#   'coSupervisor': '-',
#   'userId': 101001285,
#   'lastName': 'Wang',
#   'firstName': 'Xi',
#   'assessmentStatus': 0},
#  {'groupNo': 39,
#   'title': 'A machine learning based video player for streaming applications ',
#   'supervisor': 'Huang',
#   'coSupervisor': '-',
#   'userId': 101003945,
#   'lastName': 'Hajjar',
#   'firstName': 'George',
#   'assessmentStatus': 0},
#  {'groupNo': 39,
#   'title': 'A machine learning based video player for streaming applications ',
#   'supervisor': 'Huang',
#   'coSupervisor': '-',
#   'userId': 100963239,
#   'lastName': 'Pradel',
#   'firstName': 'Regi-ld',
#   'assessmentStatus': 0},
#  {'groupNo': 40,
#   'title': 'Building Internet of Things (IoT) and integrating Web services and Cloud computing',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 100997499,
#   'lastName': 'Howes',
#   'firstName': 'Nicholas',
#   'assessmentStatus': 0},
#  {'groupNo': 40,
#   'title': 'Building Internet of Things (IoT) and integrating Web services and Cloud computing',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101037927,
#   'lastName': 'Ibrahim',
#   'firstName': 'Samy',
#   'assessmentStatus': 0},
#  {'groupNo': 40,
#   'title': 'Building Internet of Things (IoT) and integrating Web services and Cloud computing',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101023872,
#   'lastName': 'Nhan',
#   'firstName': 'Tri',
#   'assessmentStatus': 0},
#  {'groupNo': 41,
#   'title': 'Compressed Sensing  and Recovery of ECG',
#   'supervisor': 'Rajan',
#   'coSupervisor': 'Garcia',
#   'userId': 101015307,
#   'lastName': 'Delgado Torres',
#   'firstName': 'Juan',
#   'assessmentStatus': 0},
#  {'groupNo': 41,
#   'title': 'Compressed Sensing  and Recovery of ECG',
#   'supervisor': 'Rajan',
#   'coSupervisor': 'Garcia',
#   'userId': 101008662,
#   'lastName': 'Politis',
#   'firstName': 'Diego',
#   'assessmentStatus': 0},
#  {'groupNo': 41,
#   'title': 'Compressed Sensing  and Recovery of ECG',
#   'supervisor': 'Rajan',
#   'coSupervisor': 'Garcia',
#   'userId': 100839804,
#   'lastName': 'Poole',
#   'firstName': 'Joshua',
#   'assessmentStatus': 0},
#  {'groupNo': 42,
#   'title': 'Hey Drone, can you talk?',
#   'supervisor': 'Labiche',
#   'coSupervisor': 'Rajan',
#   'userId': 101013246,
#   'lastName': 'Abdulmajeed',
#   'firstName': 'Mustafa',
#   'assessmentStatus': 0},
#  {'groupNo': 42,
#   'title': 'Hey Drone, can you talk?',
#   'supervisor': 'Labiche',
#   'coSupervisor': 'Rajan',
#   'userId': 101008746,
#   'lastName': 'Bryk',
#   'firstName': 'Thomas',
#   'assessmentStatus': 0},
#  {'groupNo': 42,
#   'title': 'Hey Drone, can you talk?',
#   'supervisor': 'Labiche',
#   'coSupervisor': 'Rajan',
#   'userId': 100688903,
#   'lastName': 'Claremont',
#   'firstName': 'Dillon',
#   'assessmentStatus': 0},
#  {'groupNo': 42,
#   'title': 'Hey Drone, can you talk?',
#   'supervisor': 'Labiche',
#   'coSupervisor': 'Rajan',
#   'userId': 101000849,
#   'lastName': 'Martin',
#   'firstName': 'Jacob',
#   'assessmentStatus': 0},
#  {'groupNo': 42,
#   'title': 'Hey Drone, can you talk?',
#   'supervisor': 'Labiche',
#   'coSupervisor': 'Rajan',
#   'userId': 101022116,
#   'lastName': 'Mazen',
#   'firstName': 'Amr',
#   'assessmentStatus': 0},
#  {'groupNo': 43,
#   'title': 'Autonomous Vehicle Tracking ',
#   'supervisor': 'Gohary',
#   'coSupervisor': 'Marsland',
#   'userId': 101050142,
#   'lastName': 'Abdelsamie',
#   'firstName': 'Ammar',
#   'assessmentStatus': 0},
#  {'groupNo': 43,
#   'title': 'Autonomous Vehicle Tracking ',
#   'supervisor': 'Gohary',
#   'coSupervisor': 'Marsland',
#   'userId': 101020551,
#   'lastName': 'Bailey',
#   'firstName': 'Jeffrey',
#   'assessmentStatus': 0},
#  {'groupNo': 43,
#   'title': 'Autonomous Vehicle Tracking ',
#   'supervisor': 'Gohary',
#   'coSupervisor': 'Marsland',
#   'userId': 101013539,
#   'lastName': 'Brockbank',
#   'firstName': 'Shane',
#   'assessmentStatus': 0},
#  {'groupNo': 43,
#   'title': 'Autonomous Vehicle Tracking ',
#   'supervisor': 'Gohary',
#   'coSupervisor': 'Marsland',
#   'userId': 101035794,
#   'lastName': "In'Airat",
#   'firstName': 'Hala',
#   'assessmentStatus': 0},
#  {'groupNo': 43,
#   'title': 'Autonomous Vehicle Tracking ',
#   'supervisor': 'Gohary',
#   'coSupervisor': 'Marsland',
#   'userId': 100996459,
#   'lastName': 'Saghbini',
#   'firstName': 'Youssef',
#   'assessmentStatus': 0},
#  {'groupNo': 44,
#   'title': 'Smart Parking Apps',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 100972921,
#   'lastName': 'Al-Salhi',
#   'firstName': 'Mohamed',
#   'assessmentStatus': 0},
#  {'groupNo': 44,
#   'title': 'Smart Parking Apps',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101010661,
#   'lastName': 'Ammouri',
#   'firstName': 'Samer',
#   'assessmentStatus': 0},
#  {'groupNo': 44,
#   'title': 'Smart Parking Apps',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101005696,
#   'lastName': 'Bishtawi',
#   'firstName': 'Ibrahim',
#   'assessmentStatus': 0},
#  {'groupNo': 49,
#   'title': 'Development of cyber-physical systems using a model-based approach ',
#   'supervisor': 'Wainer',
#   'coSupervisor': '-',
#   'userId': 101016433,
#   'lastName': 'Franco Jimenez',
#   'firstName': 'Jose de Jesus',
#   'assessmentStatus': 0},
#  {'groupNo': 49,
#   'title': 'Development of cyber-physical systems using a model-based approach ',
#   'supervisor': 'Wainer',
#   'coSupervisor': '-',
#   'userId': 100973826,
#   'lastName': 'Memon',
#   'firstName': 'Mehar',
#   'assessmentStatus': 0},
#  {'groupNo': 49,
#   'title': 'Development of cyber-physical systems using a model-based approach ',
#   'supervisor': 'Wainer',
#   'coSupervisor': '-',
#   'userId': 100838944,
#   'lastName': 'Rashidi-Tabrizi',
#   'firstName': 'Aryan',
#   'assessmentStatus': 0},
#  {'groupNo': 49,
#   'title': 'Development of cyber-physical systems using a model-based approach ',
#   'supervisor': 'Wainer',
#   'coSupervisor': '-',
#   'userId': 101017367,
#   'lastName': 'Salah Eddin',
#   'firstName': 'Majd ',
#   'assessmentStatus': 0},
#  {'groupNo': 50,
#   'title': 'A Gaming Grid ',
#   'supervisor': 'Majumdar',
#   'coSupervisor': '-',
#   'userId': 100999455,
#   'lastName': "D'Souza",
#   'firstName': 'Steven',
#   'assessmentStatus': 0},
#  {'groupNo': 50,
#   'title': 'A Gaming Grid ',
#   'supervisor': 'Majumdar',
#   'coSupervisor': '-',
#   'userId': 100996828,
#   'lastName': 'Hartford',
#   'firstName': 'Brandon',
#   'assessmentStatus': 0},
#  {'groupNo': 52,
#   'title': 'Machine Learning for Heart Sound Classification',
#   'supervisor': 'Rajan',
#   'coSupervisor': 'Esfandiari',
#   'userId': 101047976,
#   'lastName': 'Hassan',
#   'firstName': 'Musab',
#   'assessmentStatus': 0},
#  {'groupNo': 52,
#   'title': 'Machine Learning for Heart Sound Classification',
#   'supervisor': 'Rajan',
#   'coSupervisor': 'Esfandiari',
#   'userId': 101050975,
#   'lastName': 'Kamgang Nkenngni',
#   'firstName': 'Cedric',
#   'assessmentStatus': 0},
#  {'groupNo': 52,
#   'title': 'Machine Learning for Heart Sound Classification',
#   'supervisor': 'Rajan',
#   'coSupervisor': 'Esfandiari',
#   'userId': 101039762,
#   'lastName': 'Lawal',
#   'firstName': 'Lateef',
#   'assessmentStatus': 0},
#  {'groupNo': 52,
#   'title': 'Machine Learning for Heart Sound Classification',
#   'supervisor': 'Rajan',
#   'coSupervisor': 'Esfandiari',
#   'userId': 101036332,
#   'lastName': 'Nzidee',
#   'firstName': 'David',
#   'assessmentStatus': 0},
#  {'groupNo': 52,
#   'title': 'Machine Learning for Heart Sound Classification',
#   'supervisor': 'Rajan',
#   'coSupervisor': 'Esfandiari',
#   'userId': 101049874,
#   'lastName': 'Shehu',
#   'firstName': 'Abubakar',
#   'assessmentStatus': 0},
#  {'groupNo': 53,
#   'title': 'Energy Consumption Prediction',
#   'supervisor': 'Ajila',
#   'coSupervisor': '-',
#   'userId': 101063364,
#   'lastName': 'Noozhumuriyil',
#   'firstName': 'Akash',
#   'assessmentStatus': 0},
#  {'groupNo': 53,
#   'title': 'Energy Consumption Prediction',
#   'supervisor': 'Ajila',
#   'coSupervisor': '-',
#   'userId': 101024454,
#   'lastName': 'Samarase',
#   'firstName': 'Mathise',
#   'assessmentStatus': 0},
#  {'groupNo': 54,
#   'title': 'Multi-channel contactless ECG monitor',
#   'supervisor': 'Dansereau',
#   'coSupervisor': '-',
#   'userId': 101042691,
#   'lastName': 'Njoku',
#   'firstName': 'Udochukwu',
#   'assessmentStatus': 0},
#  {'groupNo': 54,
#   'title': 'Multi-channel contactless ECG monitor',
#   'supervisor': 'Dansereau',
#   'coSupervisor': '-',
#   'userId': 100937981,
#   'lastName': 'Ocloo',
#   'firstName': 'Eli',
#   'assessmentStatus': 0},
#  {'groupNo': 54,
#   'title': 'Multi-channel contactless ECG monitor',
#   'supervisor': 'Dansereau',
#   'coSupervisor': '-',
#   'userId': 101020723,
#   'lastName': 'Salamoun',
#   'firstName': 'Ha',
#   'assessmentStatus': 0},
#  {'groupNo': 54,
#   'title': 'Multi-channel contactless ECG monitor',
#   'supervisor': 'Dansereau',
#   'coSupervisor': '-',
#   'userId': 100980120,
#   'lastName': 'Van Fraassen',
#   'firstName': 'Luke',
#   'assessmentStatus': 0},
#  {'groupNo': 55,
#   'title': 'LiFi: Light Emitting Access Point',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101044984,
#   'lastName': 'Huang',
#   'firstName': 'Aaron',
#   'assessmentStatus': 0},
#  {'groupNo': 55,
#   'title': 'LiFi: Light Emitting Access Point',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 100970496,
#   'lastName': 'Sargusingh',
#   'firstName': 'Christian',
#   'assessmentStatus': 0},
#  {'groupNo': 55,
#   'title': 'LiFi: Light Emitting Access Point',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101036589,
#   'lastName': 'Zhou',
#   'firstName': 'Steven',
#   'assessmentStatus': 0},
#  {'groupNo': 56,
#   'title': 'Dose prediction using Optical Techniques',
#   'supervisor': 'Rajan',
#   'coSupervisor': '-',
#   'userId': 101015132,
#   'lastName': 'Dharmarajan',
#   'firstName': 'Kavichandiran',
#   'assessmentStatus': 0},
#  {'groupNo': 56,
#   'title': 'Dose prediction using Optical Techniques',
#   'supervisor': 'Rajan',
#   'coSupervisor': '-',
#   'userId': 101038960,
#   'lastName': 'Farah',
#   'firstName': 'Christopher',
#   'assessmentStatus': 0},
#  {'groupNo': 56,
#   'title': 'Dose prediction using Optical Techniques',
#   'supervisor': 'Rajan',
#   'coSupervisor': '-',
#   'userId': 101042784,
#   'lastName': 'Rajey',
#   'firstName': 'Omkrishan',
#   'assessmentStatus': 0},
#  {'groupNo': 56,
#   'title': 'Dose prediction using Optical Techniques',
#   'supervisor': 'Rajan',
#   'coSupervisor': '-',
#   'userId': 101025114,
#   'lastName': 'Rocco',
#   'firstName': 'Adam',
#   'assessmentStatus': 0},
#  {'groupNo': 57,
#   'title': 'Pulse monitor for sleeping mice',
#   'supervisor': 'Adler',
#   'coSupervisor': '-',
#   'userId': 101007945,
#   'lastName': 'Hou',
#   'firstName': 'Zhuoshi',
#   'assessmentStatus': 0},
#  {'groupNo': 57,
#   'title': 'Pulse monitor for sleeping mice',
#   'supervisor': 'Adler',
#   'coSupervisor': '-',
#   'userId': 100995128,
#   'lastName': 'Wang',
#   'firstName': 'Luwan',
#   'assessmentStatus': 0},
#  {'groupNo': 57,
#   'title': 'Pulse monitor for sleeping mice',
#   'supervisor': 'Adler',
#   'coSupervisor': '-',
#   'userId': 101001038,
#   'lastName': 'Wang',
#   'firstName': 'Kan',
#   'assessmentStatus': 0},
#  {'groupNo': 57,
#   'title': 'Pulse monitor for sleeping mice',
#   'supervisor': 'Adler',
#   'coSupervisor': '-',
#   'userId': 100987343,
#   'lastName': 'Wang',
#   'firstName': 'Ziqiang',
#   'assessmentStatus': 0},
#  {'groupNo': 58,
#   'title': 'Team Work Evaluation',
#   'supervisor': 'Talim',
#   'coSupervisor': '-',
#   'userId': 101002114,
#   'lastName': 'English',
#   'firstName': 'Samuel',
#   'assessmentStatus': 0},
#  {'groupNo': 58,
#   'title': 'Team Work Evaluation',
#   'supervisor': 'Talim',
#   'coSupervisor': '-',
#   'userId': 101000500,
#   'lastName': 'Erak',
#   'firstName': 'Nikola',
#   'assessmentStatus': 0},
#  {'groupNo': 58,
#   'title': 'Team Work Evaluation',
#   'supervisor': 'Talim',
#   'coSupervisor': '-',
#   'userId': 101002689,
#   'lastName': 'Turner',
#   'firstName': 'Austin',
#   'assessmentStatus': 0},
#  {'groupNo': 59,
#   'title': 'Efficient Smart Home Solution',
#   'supervisor': 'Atia',
#   'coSupervisor': '-',
#   'userId': 101001925,
#   'lastName': 'Ahmed',
#   'firstName': 'Zubaer',
#   'assessmentStatus': 0},
#  {'groupNo': 59,
#   'title': 'Efficient Smart Home Solution',
#   'supervisor': 'Atia',
#   'coSupervisor': '-',
#   'userId': 101000243,
#   'lastName': 'Almalki',
#   'firstName': 'Muaz',
#   'assessmentStatus': 0},
#  {'groupNo': 59,
#   'title': 'Efficient Smart Home Solution',
#   'supervisor': 'Atia',
#   'coSupervisor': '-',
#   'userId': 101002629,
#   'lastName': 'Dhunga-',
#   'firstName': 'Birat',
#   'assessmentStatus': 0},
#  {'groupNo': 59,
#   'title': 'Efficient Smart Home Solution',
#   'supervisor': 'Atia',
#   'coSupervisor': '-',
#   'userId': 101002933,
#   'lastName': 'Qureshi',
#   'firstName': 'Zohaib',
#   'assessmentStatus': 0},
#  {'groupNo': 59,
#   'title': 'Efficient Smart Home Solution',
#   'supervisor': 'Atia',
#   'coSupervisor': '-',
#   'userId': 100999305,
#   'lastName': 'Rahman',
#   'firstName': 'Ezwad',
#   'assessmentStatus': 0},
#  {'groupNo': 60,
#   'title': 'Content-Based Information Searching and Retrieval',
#   'supervisor': 'Majumdar',
#   'coSupervisor': '-',
#   'userId': 100997967,
#   'lastName': 'Ho',
#   'firstName': 'Kevin',
#   'assessmentStatus': 0},
#  {'groupNo': 60,
#   'title': 'Content-Based Information Searching and Retrieval',
#   'supervisor': 'Majumdar',
#   'coSupervisor': '-',
#   'userId': 100998809,
#   'lastName': 'Le',
#   'firstName': 'Vivian',
#   'assessmentStatus': 0},
#  {'groupNo': 60,
#   'title': 'Content-Based Information Searching and Retrieval',
#   'supervisor': 'Majumdar',
#   'coSupervisor': '-',
#   'userId': 101000606,
#   'lastName': 'Weaver',
#   'firstName': 'Da-',
#   'assessmentStatus': 0},
#  {'groupNo': 62,
#   'title': 'Am I engaged or disengaged?',
#   'supervisor': 'Rajan',
#   'coSupervisor': '-',
#   'userId': 100996269,
#   'lastName': 'Hussen',
#   'firstName': 'Hashim',
#   'assessmentStatus': 0},
#  {'groupNo': 62,
#   'title': 'Am I engaged or disengaged?',
#   'supervisor': 'Rajan',
#   'coSupervisor': '-',
#   'userId': 100982801,
#   'lastName': 'Kukhta',
#   'firstName': 'Benjamin',
#   'assessmentStatus': 0},
#  {'groupNo': 62,
#   'title': 'Am I engaged or disengaged?',
#   'supervisor': 'Rajan',
#   'coSupervisor': '-',
#   'userId': 101006614,
#   'lastName': 'Osman',
#   'firstName': 'Mohamed',
#   'assessmentStatus': 0},
#  {'groupNo': 62,
#   'title': 'Am I engaged or disengaged?',
#   'supervisor': 'Rajan',
#   'coSupervisor': '-',
#   'userId': 101002418,
#   'lastName': 'Sheikh-Omar',
#   'firstName': 'Umar',
#   'assessmentStatus': 0},
#  {'groupNo': 62,
#   'title': 'Am I engaged or disengaged?',
#   'supervisor': 'Rajan',
#   'coSupervisor': '-',
#   'userId': 100998555,
#   'lastName': 'Wiles',
#   'firstName': 'Matthew',
#   'assessmentStatus': 0},
#  {'groupNo': 63,
#   'title': 'Modelling and Simulation of Biomedical Devices',
#   'supervisor': 'Coordi-tor',
#   'coSupervisor': '-',
#   'userId': 100994082,
#   'lastName': 'Lasisi',
#   'firstName': 'Anjolaoluwa',
#   'assessmentStatus': 0},
#  {'groupNo': 64,
#   'title': 'Smart Scale for Monitoring Patient Body Parameters',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101020987,
#   'lastName': 'Elalem',
#   'firstName': 'Mohamed',
#   'assessmentStatus': 0},
#  {'groupNo': 64,
#   'title': 'Smart Scale for Monitoring Patient Body Parameters',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101021710,
#   'lastName': 'Faizal',
#   'firstName': 'Adeek',
#   'assessmentStatus': 0},
#  {'groupNo': 64,
#   'title': 'Smart Scale for Monitoring Patient Body Parameters',
#   'supervisor': 'Lung',
#   'coSupervisor': '-',
#   'userId': 101013607,
#   'lastName': 'Quansah',
#   'firstName': 'Bodee',
#   'assessmentStatus': 0},
#  {'groupNo': 65,
#   'title': 'Direction Finder',
#   'supervisor': 'Coordi-tor',
#   'coSupervisor': '-',
#   'userId': 101007378,
#   'lastName': 'Agarwal',
#   'firstName': 'Ma-s',
#   'assessmentStatus': 0},
#  {'groupNo': 66,
#   'title': 'Detecting Sign Language via a Wearable Device',
#   'supervisor': 'Coordi-tor',
#   'coSupervisor': '-',
#   'userId': 101020390,
#   'lastName': 'Alsayed',
#   'firstName': 'Ahmed',
#   'assessmentStatus': 0},
#  {'groupNo': 66,
#   'title': 'Detecting Sign Language via a Wearable Device',
#   'supervisor': 'Coordi-tor',
#   'coSupervisor': '-',
#   'userId': 101014387,
#   'lastName': 'Kulenthiran',
#   'firstName': 'Ja-rth',
#   'assessmentStatus': 0},
#  {'groupNo': 67,
#   'title': 'Video transmission via  LTE-connected UAVs',
#   'supervisor': 'Yanikomeroglu',
#   'coSupervisor': '-',
#   'userId': 100962487,
#   'lastName': 'Guo',
#   'firstName': 'Haoyang',
#   'assessmentStatus': 0},
#  {'groupNo': 67,
#   'title': 'Video transmission via  LTE-connected UAVs',
#   'supervisor': 'Yanikomeroglu',
#   'coSupervisor': '-',
#   'userId': 100978595,
#   'lastName': 'Harvey',
#   'firstName': 'Ian',
#   'assessmentStatus': 0},
#  {'groupNo': 67,
#   'title': 'Video transmission via  LTE-connected UAVs',
#   'supervisor': 'Yanikomeroglu',
#   'coSupervisor': '-',
#   'userId': 101053479,
#   'lastName': 'Yusuf',
#   'firstName': 'Hassan',
#   'assessmentStatus': 0},
#  {'groupNo': 68,
#   'title': 'Topic TBC',
#   'supervisor': 'Schwartz',
#   'coSupervisor': '-',
#   'userId': 101038735,
#   'lastName': 'Labelle',
#   'firstName': 'Adam',
#   'assessmentStatus': 0},
#  {'groupNo': 68,
#   'title': 'Topic TBC',
#   'supervisor': 'Schwartz',
#   'coSupervisor': '-',
#   'userId': 101019133,
#   'lastName': 'Marasinghe',
#   'firstName': 'Shaviyo',
#   'assessmentStatus': 0},
#  {'groupNo': 68,
#   'title': 'Topic TBC',
#   'supervisor': 'Schwartz',
#   'coSupervisor': '-',
#   'userId': 101018883,
#   'lastName': 'Ranjan Philip',
#   'firstName': 'Brian',
#   'assessmentStatus': 0},
#  {'groupNo': 68,
#   'title': 'Topic TBC',
#   'supervisor': 'Schwartz',
#   'coSupervisor': '-',
#   'userId': 101037387,
#   'lastName': 'Sharma',
#   'firstName': 'Shivanshi',
#   'assessmentStatus': 0},
#  {'groupNo': 69,
#   'title': 'Topic TBC',
#   'supervisor': 'Taha',
#   'coSupervisor': 'Atia',
#   'userId': 101050477,
#   'lastName': 'Turner',
#   'firstName': 'John',
#   'assessmentStatus': 0},
#  {'groupNo': 69,
#   'title': 'Topic TBC',
#   'supervisor': 'Taha',
#   'coSupervisor': 'Atia',
#   'userId': 101023182,
#   'lastName': 'Vuong',
#   'firstName': 'Aaron',
#   'assessmentStatus': 0},
#  {'groupNo': 69,
#   'title': 'Topic TBC',
#   'supervisor': 'Taha',
#   'coSupervisor': 'Atia',
#   'userId': 101027686,
#   'lastName': 'Wang',
#   'firstName': 'Alden',
#   'assessmentStatus': 0},
#  {'groupNo': 70,
#   'title': 'Energy Consumption Prediction',
#   'supervisor': 'Ajila',
#   'coSupervisor': '-',
#   'userId': 101054547,
#   'lastName': 'Mehdi',
#   'firstName': 'Zoha',
#   'assessmentStatus': 0},
#  {'groupNo': 70,
#   'title': 'Energy Consumption Prediction',
#   'supervisor': 'Ajila',
#   'coSupervisor': '-',
#   'userId': 101039656,
#   'lastName': 'Singh',
#   'firstName': 'Amandeep',
#   'assessmentStatus': 0}]

# %%
# saving to mongo db database 

for r in jf_data:
    rpush = db.insert_one(r)
    #print('multiple posts:{0}'.format(rpush.id))
# how to avoid getting duplicates values in database ??

# %%
# creating a query
my_query = {"Group No": 52}

# %%
# quering the database for matching values 
mydoc = mycol.find(my_query)
mydoc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-1633c950796f> in <module>
#       1 # quering the database for matching values
# ----> 2 mydoc = mycol.find(my_query)
#       3 mydoc
#
# NameError: name 'mycol' is not defined

# %%
# printing the matched values 

for x in mydoc:
   print(x)
# Out:
# {'_id': ObjectId('5e502c182498f99b0226a2b0'), 'Group No': 52.0, 'Title': 'Crowd-source grocery store layouts for dynamically sorted shopping lists', 'Supervisor': 'Green', 'Co-supervisor': None, 'ID Number': 1.0, 'Last name': 'McConnell', 'First name': 'Jenna', 'Assessment Status': 0.0}
# {'_id': ObjectId('5e502c182498f99b0226a2b1'), 'Group No': 52.0, 'Title': 'Crowd-source grocery store layouts for dynamically sorted shopping lists', 'Supervisor': 'Green', 'Co-supervisor': None, 'ID Number': 2.0, 'Last name': 'Warmington', 'First name': 'Saundra', 'Assessment Status': 0.0}
# {'_id': ObjectId('5e502c182498f99b0226a2b2'), 'Group No': 52.0, 'Title': 'Crowd-source grocery store layouts for dynamically sorted shopping lists', 'Supervisor': 'Green', 'Co-supervisor': None, 'ID Number': 3.0, 'Last name': 'Poll', 'First name': 'Jennifer', 'Assessment Status': 0.0}

# %%
# database saving in SQL 
import mysql.connector as mysql

# %%
# database configuration details 

db = mysql.connect(
  host="localhost",
  user="root",
  passwd="root123"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-57ba5cb5a63d> in <module>
#       1 # database configuration details
#       2
# ----> 3 db = mysql.connect(
#       4   host="localhost",
#       5   user="root",
#
# NameError: name 'mysql' is not defined

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'assessment_test')

# %%
mycursor = mydb.cursor()
mycursor.execute("CREATE DATABASE sAssessment")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-7935eb3a44e4> in <module>
# ----> 1 mycursor = mydb.cursor()
#       2 mycursor.execute("CREATE DATABASE sAssessment")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\collection.py in __call__(self, *args, **kwargs)
#    3337                             "object it is failing because no such method "
#    3338                             "exists." %
# -> 3339                             self.__name)
#    3340         raise TypeError("'Collection' object is not callable. If you meant to "
#    3341                         "call the '%s' method on a 'Collection' object it is "
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'cursor' method on a 'Database' object it is failing because no such method exists.

# %%
# html table using python 

from flask_table import Table,Col

# %%
class ItemTable(Table):
    name = Col('Name')
    description = Col('Description')
    
# Get some objects
class Item(object):
    def __init__(self, name, description):
        self.name = name
        self.description = description
        
items = [Item('Name1', 'Description1'),
         Item('Name2', 'Description2'),
         Item('Name3', 'Description3')]
# Or, equivalently, some dicts
items = [dict(name='Name1', description='Description1'),
         dict(name='Name2', description='Description2'),
         dict(name='Name3', description='Description3')]

# Or, more likely, load items from your database with something like
#items = ItemModel.query.all()

# Populate the table
table = ItemTable(items)

# Print the html
print(table.__html__())
# or just {{ table }} from within a Jinja template
# Out:
# <table>
# <thead><tr><th>Name</th><th>Description</th></tr></thead>
# <tbody>
# <tr><td>Name1</td><td>Description1</td></tr>
# <tr><td>Name2</td><td>Description2</td></tr>
# <tr><td>Name3</td><td>Description3</td></tr>
# </tbody>
# </table>

# %%
# reading the rubics and saving to database 
ru = pd.read_excel('rubicsMetrix.xlsx',index_col=[0])
ru['metrics'] = ru.index
ru=ru.T
rud = ru.to_dict()
rud
rd = json.dumps(rud)
rd
# Out:
# '{"Instructions ": {"Beginning": "Weak understanding; works is inaccurate and significant redirection is required. Directions are disorganized, inaccurate and incomplete.", "Developing": "Basic understanding; main ideas are followed but missing detail. Directions are adequate but incomplete; sufficiently conveys basic concepts, but lacks accuracy and specificity. ", "Accomplished": "Mostly understood; work is largely accurate and little redirection is required. Directions are organized and appropriate; language is clear and mostly error-free.", "Exemplary": "Fully understood; work is focused and accurate; no redirection is  required. Directions are cohesive and easy to follow; language is concise, specific and descriptive. ", "metrics": "Instructions "}, "Self-awareness ": {"Beginning": "Not focused on studies; no clear career goals or extracurricular interests; no attempt to self-direct or self-evaluate; no curiosity or initiative toward new subjects; unaware of the need to stay current; does not recognize personal limitations and the need to seek advice; constructive feedback is not well received.", "Developing": "Basic academic and extracurricular efforts are being put forth; vague career goals; limited self-direction and self-evaluation; minimal curiosity and initiative toward new subjects; basic awareness of the need to stay current; limited awareness of personal limitations and when to seek advice; limited ability to handle constructive feedback.", "Accomplished": "Good academic and extracurricular efforts; clear career goals; engages in self-direction and self-evaluation; curiosity and initiative toward new subjects is evident; understands the need to stay current; aware of personal limitations and when to seek advice; constructive feedback is well received.", "Exemplary": "Excels academically and in extracurricular activities; clear career goals with detailed plans; actively engages in self-direction and self-evaluation; high level of curiosity and initiative toward new subjects; thoroughly engaged in the need to stay current; accurate assessment of personal limitations when to seek advice; skillfully accepts and uses constructive feedback.", "metrics": "Self-awareness "}, "Information from relevant publications": {"Beginning": "Reads only assigned materials; is not aware of relevant publications; does not look beyond information provided in class; makes little effort to independently find additional information.  ", "Developing": "Minimal consultation with outside materials; limited awareness of relevant publications; does not explore sources in details and often stops at first source without concern for credibility.", "Accomplished": "Regularly goes beyond assigned materials; reasonable awareness of relevant publications; able to independently locate required information and assess credibility of sources.", "Exemplary": "Actively seeks out additional materials; extensive knowledge of relevant publications; finds advanced information to further personal learning; thoroughly considers multiple sources with accurate assessment of both relevance and credibility.", "metrics": "Information from relevant publications"}}'

# %%
jf= rub.to_json(orient='records') # converting datframes 
jf_data = json.loads(jf) # converting to dictionary 
jf_data
# Out:
# [{'metric': 'Instructions ',
#   'Beginning': 'Weak understanding; works is inaccurate and significant redirection is required. Directions are disorganized, inaccurate and incomplete.',
#   'Developing': 'Basic understanding; main ideas are followed but missing detail. Directions are adequate but incomplete; sufficiently conveys basic concepts, but lacks accuracy and specificity. ',
#   'Accomplished': 'Mostly understood; work is largely accurate and little redirection is required. Directions are organized and appropriate; language is clear and mostly error-free.',
#   'Exemplary': 'Fully understood; work is focused and accurate; no redirection is  required. Directions are cohesive and easy to follow; language is concise, specific and descriptive. '},
#  {'metric': 'Self-awareness ',
#   'Beginning': 'Not focused on studies; no clear career goals or extracurricular interests; no attempt to self-direct or self-evaluate; no curiosity or initiative toward new subjects; unaware of the need to stay current; does not recognize personal limitations and the need to seek advice; constructive feedback is not well received.',
#   'Developing': 'Basic academic and extracurricular efforts are being put forth; vague career goals; limited self-direction and self-evaluation; minimal curiosity and initiative toward new subjects; basic awareness of the need to stay current; limited awareness of personal limitations and when to seek advice; limited ability to handle constructive feedback.',
#   'Accomplished': 'Good academic and extracurricular efforts; clear career goals; engages in self-direction and self-evaluation; curiosity and initiative toward new subjects is evident; understands the need to stay current; aware of personal limitations and when to seek advice; constructive feedback is well received.',
#   'Exemplary': 'Excels academically and in extracurricular activities; clear career goals with detailed plans; actively engages in self-direction and self-evaluation; high level of curiosity and initiative toward new subjects; thoroughly engaged in the need to stay current; accurate assessment of personal limitations when to seek advice; skillfully accepts and uses constructive feedback.'},
#  {'metric': 'Information from relevant publications',
#   'Beginning': 'Reads only assigned materials; is not aware of relevant publications; does not look beyond information provided in class; makes little effort to independently find additional information.  ',
#   'Developing': 'Minimal consultation with outside materials; limited awareness of relevant publications; does not explore sources in details and often stops at first source without concern for credibility.',
#   'Accomplished': 'Regularly goes beyond assigned materials; reasonable awareness of relevant publications; able to independently locate required information and assess credibility of sources.',
#   'Exemplary': 'Actively seeks out additional materials; extensive knowledge of relevant publications; finds advanced information to further personal learning; thoroughly considers multiple sources with accurate assessment of both relevance and credibility.'}]

# %%
# pushing rubics to mongo db database 
for r in jf_data:
    rpush = mycol.insert_one(r)

# %%
# Out:
# ['metric', 'Beginning', 'Developing', 'Accomplished', 'Exemplary']

# %%
ru = pd.read_excel('rubicsMetrix.xlsx')
#ru['metrics'] = ru.index
ru
# Out:
#                                            Indicator  \
# 0             6.1 Personal and group time management
# 1                  6.2 Group culture, group dynamics
# 2  6.3 Leadership: initiative and mentoring, area...
#
#                                            Beginning  \
# 0  Deadlines often missed. Several projects or as...
# 1  Not dependable. Little or no trust from teamma...
# 2  No initiative. No effort to mentor group membe...
#
#                                           Developing  \
# 0  Some deadlines missed. Some tasks or assignmen...
# 1  Usually dependable and trusted by teammates. M...
# 2  Some initiative. Some effort to mentor group m...
#
#                                         Accomplished  \
# 0  No important deadlines missed. Few tasks or as...
# 1  Dependable and trusted by teammates. Ethical o...
# 2  Good initiative and self-motivation. Regular e...
#
#                                            Exemplary
# 0  No deadlines missed. Tasks and assignments alw...
# 1  Dependable and trusted by teammates. Ethical a...
# 2  Self-motivated, with regular demonstration of ...

# %%
type(ru)
# Out:
# pandas.core.frame.DataFrame

# %% [raw]
# list(data.columns)

# %%
count(ru)
# Out:
# ['Indicator', 'Beginning', 'Developing', 'Accomplished', 'Exemplary']

# %%
ru['Beginning'][0]
# Out:
# 'Deadlines often missed. Several projects or assignments appear hurried or inadequately addressed. No evidence of time management planning.'

# %%
list(ru.columns)
# Out:
# ['Indicator',
#  'Level 1: Beginning',
#  'Level 2: Developing',
#  'Level 3: Accomplished',
#  'Level 4: Exemplary']

# %%
ru.reset_index(inplace=False)
data_dict = ru.to_dict("records")

# %%
data_dict
# Out:
# [{'Indicator': '6.1 Personal and group time management',
#   'Beginning': 'Deadlines often missed. Several projects or assignments appear hurried or inadequately addressed. No evidence of time management planning.',
#   'Developing': 'Some deadlines missed. Some tasks or assignments appear hurried or inadequately addressed. Some evidence of time management planning.',
#   'Accomplished': 'No important deadlines missed. Few tasks or assignments appear hurried or inadequately addressed. Good time management planning.',
#   'Exemplary': 'No deadlines missed. Tasks and assignments always excellently prepared and presented. Tasks occasionally completed ahead of schedule. Leadership in time planning.'},
#  {'Indicator': '6.2 Group culture, group dynamics',
#   'Beginning': 'Not dependable. Little or no trust from teammates. Dishonest or evasive interactions with teammates. Poor conflict resolution.',
#   'Developing': 'Usually dependable and trusted by teammates. Mostly ethical behavior towards project and teammates. Minor conflicts.',
#   'Accomplished': 'Dependable and trusted by teammates. Ethical open interactions with teammates. Good conflict resolution.',
#   'Exemplary': 'Dependable and trusted by teammates. Ethical and open interactions with teammates. Leads team in ethical and responsive behavior. Leadership in conflict resolution.'},
#  {'Indicator': '6.3 Leadership: initiative and mentoring, areas of expertise, and interdisciplinary teams',
#   'Beginning': 'No initiative. No effort to mentor group members or take ownership of an area of expertise.',
#   'Developing': 'Some initiative. Some effort to mentor group members and take ownership of an area of expertise.',
#   'Accomplished': 'Good initiative and self-motivation. Regular effort to mentor group members. Clear command of an area of expertise.',
#   'Exemplary': 'Self-motivated, with regular demonstration of initiative. Constructively directs other team members and helps them to improve at their tasks. High degree of knowledge in an area of expertise.'}]

# %%
# pushing rubics to mongo db database 
for r in data_dict:
    rpush = mycol.insert_one(r)

# %%
db.delete_many({})
